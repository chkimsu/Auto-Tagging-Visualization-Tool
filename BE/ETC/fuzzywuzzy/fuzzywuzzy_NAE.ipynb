# %%
import os
os.chdir('/data01/CSB/CSB_Jupyter/ATVT/BERT/CSB_Modelling/fuzzywuzzy/')

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', -1)
data = pd.read_csv('NAE02_result.csv')
data = data[~pd.isnull(data.PROP_DESCRIPTION)]
data = data.drop(['Unnamed: 0'], axis=1)
# Out:
# /home/chkimsu/anaconda3/envs/csb2/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
a = pd.read_csv('AHUs.txt', header=None)
a.columns = ['a']
a = list(a.a)
b = []
c = list(data['PROP_DESCRIPTION'])

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd


finaldata = pd.DataFrame(columns=('rawdata', 'label'), index = range(len(c)))


for i in range(len(c)):
    for j in range(len(a)):
        
        b.append(fuzz.ratio(c[i], a[j]))
    finaldata.loc[i, 'rawdata'] = c[i]
    finaldata.loc[i, 'label'] = a[b.index(max(b))]
    b.clear()

# print("after_finaldata:", finaldata)

# %%
data['label'] = None
rawdata = pd.read_csv('NAE02_result.csv')
rawdata['label'] = None

j = 0
for i in list(data.index):
    rawdata.loc[i, 'label'] = finaldata.iloc[j,1]
    j +=1
    
rawdata.drop(['Unnamed: 0'], axis = 1).to_csv('NAE02_fuzzy.csv')

# %%
finaldata.columns = ['PROP_DESCRIPTION', 'label']

# %%
pd.read_csv('AHUs.txt')
# Out:
#            ahus discharge air temp sensor
# 0   ahus discharge air humidity sensor
# 1   ahus discharge air pressure sensor
# 2   ahus discharge air flow sensor
# 3   ahus discharge air fan cmd
# 4   ahus discharge air fan sensor
# 5   ahus return air temp sensor
# 6   ahus return air humidity sensor
# 7   ahus return air pressure sensor
# 8   ahus return air flow sensor
# 9   ahus return air co2 sensor
# 10  ahus return air fan cmd
# 11  ahus return air damper cmd
# 12  ahus mixed air temp sensor
# 13  ahus outside air temp sensor
# 14  ahus outside air humidity sensor
# 15  ahus outside air pressure sensor
# 16  ahus outside air flow sensor
# 17  ahus outside air flow sp
# 18  ahus outside air damper cmd
# 19  ahus exhaust air fan cmd
# 20  ahus exhaust air damper cmd
# 21  ahus cool stage cmd
# 22  ahus heat stage cmd
# 23  ahus humidifier cmd
# 24  ahus freezStat sensor
# 25  ahus heatWheel cmd
# 26  ahus facdBypass cmd
# 27  ahus bypass damper cmd
# 28  ahus zone air temp sensor
# 29  ahus zone air temp effective sp
# 30  ahus zone air temp occ cooling sp
# 31  ahus zone air temp unocc cooling sp
# 32  ahus zone air temp unocc heating sp
# 33  ahus zone air temp standby cooling sp
# 34  ahus zone air temp standby heating sp
# 35  ahus zone air humidity sensor
# 36  ahus zone air co2 sensor
# 37  ahus zone air co2 sp

# %%
finaldata
# Out:
#                 PROP_DESCRIPTION                            label
# 0     15th floor mechanical room  ahus zone air temp effective sp
# 1     Zone2 Temperature           ahus zone air temp sensor
# 2     Zone 1 Temperature          ahus zone air temp sensor
# 3     Zone2 Temperature           ahus zone air temp sensor
# 4     Zone 1 Temperature          ahus zone air temp sensor
# ...                  ...                                ...
# 2053  Mode                        ahus outside air flow sp
# 2054  State                       ahus freezStat sensor
# 2055  Input (Enum)                ahus exhaust air fan cmd
# 2056  Hour counter [h]            ahus cool stage cmd
# 2057  Serial Number [number]      ahus humidifier cmd
#
# [2058 rows x 2 columns]
